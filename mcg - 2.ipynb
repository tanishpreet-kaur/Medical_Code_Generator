# %% [markdown]
# ## Medical Code Generator

# %% [markdown]
# Healthcare documentation often contains detailed doctor–patient conversations that must be converted into structured medical records for billing, clinical documentation, and analysis.
#
# Medical coders typically review these conversations and assign standardized codes such as ICD-10 (International Classification of Diseases) for diagnoses and HCPCS (Healthcare Common Procedure Coding System) for procedures and services.

# %% [markdown]
# The goal of this project is to design and implement a retrieval-augmented LLM pipeline that extracts key medical information from clinical conversations, retrieves relevant codes from provided ICD-10 and HCPCS datasets, and outputs a structured response.

# %% [markdown]
# **Conversation → Medical Entity Extraction → Code Retrieval (Excel only) → LLM Validation → Structured Output**

# %% [markdown]
# **ICD-10** is a medical coding system used to classify diseases, conditions, symptoms, and causes of death. It is maintained by the World Health Organization.
#
# It helps healthcare providers:
# - Record diagnoses
# - Track diseases and health conditions
# - Maintain medical records
# - Perform health statistics and research

# %% [markdown]
# **HCPCS** is a medical coding system used to describe medical services, procedures, equipment, and supplies. It is mainly used in medical billing and insurance claims.
#
# It helps healthcare providers:
# - Bill insurance companies
# - Identify medical procedures
# - Track medical services

# %% [markdown]
# #### 1. Handling files containing ICD-10 and HCPCS Codes

# %%
# read the ICD-10 and HCPCS code files
import pandas as pd
import openpyxl 
icd_df = pd.read_excel("ICD-10 Codes.xlsx")
hcpcs_df = pd.read_csv("HCPCS Codes.csv", encoding="latin1")

# %% [markdown]
# ICD-10 dataset

# %%
# inspect the dataframes
icd_df.head()
# Out:
#     CODE            SHORT DESCRIPTION (VALID ICD-10 FY2024)  \
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis
#
#               LONG DESCRIPTION (VALID ICD-10 FY2024)
# 0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2                               Cholera, unspecified
# 3                         Typhoid fever, unspecified
# 4                                 Typhoid meningitis

# %%
icd_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 73201 entries, 0 to 73200
# Data columns (total 3 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CODE                                     73201 non-null  str
#  1   SHORT DESCRIPTION (VALID ICD-10 FY2024)  73201 non-null  str
#  2   LONG DESCRIPTION (VALID ICD-10 FY2024)   73199 non-null  str
# dtypes: str(3)
# memory usage: 1.7 MB

# %%
# rename columns 
icd_df = icd_df.rename(columns={
    "CODE": "code",
    "SHORT DESCRIPTION (VALID ICD-10 FY2024)": "short_description",
    "LONG DESCRIPTION (VALID ICD-10 FY2024)": "long_description"
})

# %% [markdown]
# HCPCS Dataset

# %%
# inspect the dataframes
hcpcs_df.head()
# Out:
#   LIST OF CPT1/HCPCS CODES USED TO DEFINE CERTAIN DESIGNATED HEALTH SERVICE CATEGORIES2 UNDER SECTION 1877 OF THE SOCIAL SECURITY ACT  \
# 0                                                NaN
# 1        This code list is effective January 1, 2024
# 2                                                NaN
# 3                       CLINICAL LABORATORY SERVICES
# 4                                                NaN
#
#   Unnamed: 1
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# drop rows with missing values
hcpcs_df.dropna(inplace=True)

# %%
hcpcs_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1211 entries, 7 to 1248
# Data columns (total 2 columns):
#  #   Column                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                               --------------  -----
#  0   LIST OF CPT1/HCPCS CODES USED TO DEFINE CERTAIN DESIGNATED HEALTH SERVICE CATEGORIES2 UNDER SECTION 1877 OF THE SOCIAL SECURITY ACT  1211 non-null   str
#  1   Unnamed: 1                                                                                                                           1211 non-null   str
# dtypes: str(2)
# memory usage: 28.4 KB

# %%
# rename columns
hcpcs_df = hcpcs_df.rename(columns={
    "LIST OF CPT1/HCPCS CODES USED TO DEFINE CERTAIN DESIGNATED HEALTH SERVICE CATEGORIES2 UNDER SECTION 1877 OF THE SOCIAL SECURITY ACT": "code",
    "Unnamed: 1": "description"
})

# %% [markdown]
# #### 2. Convert DataFrames to LangChain Documents

# %%
from langchain_core.documents import Document

# document is the basic unit stored in vector database. 
# empty list stores all codes before sending them to vector store
documents = []

# ICD10
for _, row in icd_df.iterrows():
    documents.append(
        # iterate through each row and add the document containing code, description and metadata to the list
        Document(
            page_content=f"ICD10 Code: {row['code']}\nDescription: {row['short_description']} {row['long_description']}",
            metadata={
                "code": row["code"],
                "type": "ICD10"
            }
        )
    )

# HCPCS
for _, row in hcpcs_df.iterrows():
    documents.append(
        # iterate through each row and add the document containing code, description and metadata to the list
        Document(
            page_content=f"HCPCS Code: {row['code']}\nDescription: {row['description']}",
            metadata={
                "code": row["code"],
                "type": "HCPCS"
            }
        )
    )

print("Total documents:", len(documents))
# Out:
# Total documents: 74412

# %% [markdown]
# #### 3. Create embeddings to convert text into vectors

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# embedding model is created to convert text data into vectors for semantic search
embeddings = HuggingFaceEmbeddings(
    model_name="pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 45740.16it/s]
# BertModel LOAD REPORT from: pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# #### 4. Create Vector Database to store embeddings for retrieval

# %%
from langchain_community.vectorstores import FAISS

vectorstore = FAISS.from_documents(documents, embeddings)
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={
        "k": 30,
        "fetch_k": 50
    }
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 from langchain_community.vectorstores import FAISS
# ----> 3 vectorstore = FAISS.from_documents(documents, embeddings)
#       4 retriever = vectorstore.as_retriever(
#       5     search_type="mmr",
#       6     search_kwargs={
#    (...)     10     }
#      11 )
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:155, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     145 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     146     """Compute doc embeddings using a HuggingFace transformer model.
#     147
#     148     Args:
#    (...)    153
#     154     """
# --> 155     return self._embed(texts, self.encode_kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:130, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     128     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     129 else:
# --> 130     embeddings = self._client.encode(
#     131         texts,
#     132         show_progress_bar=self.show_progress,
#     133         **encode_kwargs,
#     134     )
#     136 if isinstance(embeddings, list):
#     137     msg = (
#     138         "Expected embeddings to be a Tensor or a numpy array, "
#     139         "got a list instead."
#     140     )
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\sentence_transformers\models\Transformer.py:262, in Transformer.forward(self, features, **kwargs)
#     239 """
#     240 Forward pass through the transformer model.
#     241
#    (...)    258         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     259 """
#     260 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 262 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     263 token_embeddings = outputs[0]
#     264 features["token_embeddings"] = token_embeddings
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\utils\generic.py:917, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#     915             output = func(self, *args, **kwargs)
#     916     else:
# --> 917         output = func(self, *args, **kwargs)
#     918 # Restore original config value
#     919 finally:
#     920     if is_causal is not None:
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\utils\output_capturing.py:253, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     251 # Run the forward
#     252 try:
# --> 253     outputs = func(self, *args, **kwargs)
#     254 # Reset the states
#     255 finally:
#     256     _active_collector.reset(output_token)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:697, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     680 embedding_output = self.embeddings(
#     681     input_ids=input_ids,
#     682     position_ids=position_ids,
#    (...)    685     past_key_values_length=past_key_values_length,
#     686 )
#     688 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     689     attention_mask=attention_mask,
#     690     encoder_attention_mask=encoder_attention_mask,
#    (...)    694     past_key_values=past_key_values,
#     695 )
# --> 697 encoder_outputs = self.encoder(
#     698     embedding_output,
#     699     attention_mask=attention_mask,
#     700     encoder_hidden_states=encoder_hidden_states,
#     701     encoder_attention_mask=encoder_attention_mask,
#     702     past_key_values=past_key_values,
#     703     use_cache=use_cache,
#     704     cache_position=cache_position,
#     705     position_ids=position_ids,
#     706     **kwargs,
#     707 )
#     708 sequence_output = encoder_outputs.last_hidden_state
#     709 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:452, in BertEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     440 def forward(
#     441     self,
#     442     hidden_states: torch.Tensor,
#    (...)    449     **kwargs: Unpack[TransformersKwargs],
#     450 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     451     for i, layer_module in enumerate(self.layer):
# --> 452         hidden_states = layer_module(
#     453             hidden_states,
#     454             attention_mask,
#     455             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     456             encoder_attention_mask=encoder_attention_mask,
#     457             past_key_values=past_key_values,
#     458             cache_position=cache_position,
#     459             **kwargs,
#     460         )
#     462     return BaseModelOutputWithPastAndCrossAttentions(
#     463         last_hidden_state=hidden_states,
#     464         past_key_values=past_key_values if use_cache else None,
#     465     )
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:397, in BertLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     387 def forward(
#     388     self,
#     389     hidden_states: torch.Tensor,
#    (...)    395     **kwargs: Unpack[TransformersKwargs],
#     396 ) -> tuple[torch.Tensor]:
# --> 397     self_attention_output, _ = self.attention(
#     398         hidden_states,
#     399         attention_mask,
#     400         past_key_values=past_key_values,
#     401         cache_position=cache_position,
#     402         **kwargs,
#     403     )
#     404     attention_output = self_attention_output
#     406     if self.is_decoder and encoder_hidden_states is not None:
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:326, in BertAttention.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     315 def forward(
#     316     self,
#     317     hidden_states: torch.Tensor,
#    (...)    323     **kwargs: Unpack[TransformersKwargs],
#     324 ) -> tuple[torch.Tensor]:
#     325     attention_mask = attention_mask if not self.is_cross_attention else encoder_attention_mask
# --> 326     attention_output, attn_weights = self.self(
#     327         hidden_states,
#     328         encoder_hidden_states=encoder_hidden_states,
#     329         attention_mask=attention_mask,
#     330         past_key_values=past_key_values,
#     331         cache_position=cache_position,
#     332         **kwargs,
#     333     )
#     334     attention_output = self.output(attention_output, hidden_states)
#     335     return attention_output, attn_weights
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\transformers\models\bert\modeling_bert.py:180, in BertSelfAttention.forward(self, hidden_states, attention_mask, past_key_values, cache_position, **kwargs)
#     177 hidden_shape = (*input_shape, -1, self.attention_head_size)
#     179 # get all proj
# --> 180 query_layer = self.query(hidden_states).view(*hidden_shape).transpose(1, 2)
#     181 key_layer = self.key(hidden_states).view(*hidden_shape).transpose(1, 2)
#     182 value_layer = self.value(hidden_states).view(*hidden_shape).transpose(1, 2)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\Balvi\OneDrive\Desktop\IDS\.venv\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# #### 5. Defined Structured Output using Pydantic

# %%
from pydantic import BaseModel
from typing import List

class MedicalOutput(BaseModel):
    summary: str
    ICD10: List[str]
    HCPCS: List[str]

# %% [markdown]
# #### 6. Create LLM

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash")
structured_model = model.with_structured_output(MedicalOutput)

# %% [markdown]
# #### 7. Create Output Parser

# %%
from langchain_core.output_parsers import PydanticOutputParser

parser = PydanticOutputParser(pydantic_object=MedicalOutput)

# %% [markdown]
# #### 8. Create Prompts

# %%
from langchain_core.messages import SystemMessage, HumanMessage

system_prompt = SystemMessage(
content = f"""
You are an expert medical coder. Analyze the conversation and assign ONLY relevant ICD-10 diagnosis codes and HCPCS procedure codes.

CRITICAL RULES:
1. ALWAYS assign ICD-10 codes for ALL diagnoses mentioned (e.g., Type 2 diabetes → E11.*, hypertension → I10/I11.*).
2. Use ONLY codes from the retrieved documents below - check exact matches.
3. For procedures/exams (foot exam, labs), use HCPCS codes.
4. Do NOT leave ICD10 empty if diagnoses are present.
5. List multiple codes if multiple conditions.

Format EXACTLY as requested below.
{parser.get_format_instructions()}
""")

# %% [markdown]
# #### 9. Build Pipeline

# %%
def medical_coder(conversation):
    docs = retriever.invoke(conversation)
    context = "\n".join(
    [
        f"{d.metadata['type']} Code: {d.metadata['code']}\n{d.page_content}"
        for d in docs
    ]
)

    human_prompt = HumanMessage(
        content=f"""
            Conversation:{conversation}
            Relevant coding documents:{context}
            """
        )

    response = model.invoke([system_prompt, human_prompt])
    return parser.parse(response.content)

# %% [markdown]
# #### 10. Give input to LLM

# %%
conversation = open("case1.txt").read()
result = medical_coder(conversation)
print(result)
# Out:
# summary="The patient is a follow-up for chronic medical problems including Type 2 diabetes mellitus with diabetic polyneuropathy, dyslipidemia, and primary hypertension. The patient's medications (lisinopril, atorvastatin, metformin, glimepiride) are reviewed and continued. Blood pressure is slightly elevated, and home monitoring is advised. A diabetic foot exam was performed, revealing absent sensation to monofilament on both feet and hard skin on the right foot. Labs ordered include CBC, CMP, HbA1c, Vitamin B12, urine microalbumin, and a lipid panel. Due to the limitations of the provided coding documents, specific ICD-10 codes for the patient's chronic conditions could not be assigned as they were not present in the retrieved documents. Only the HCPCS code for the lipid panel was applicable from the provided list." ICD10=[] HCPCS=['80061']

# %%
result.summary
# Out:
# "The patient is a follow-up for chronic medical problems including Type 2 diabetes mellitus with diabetic polyneuropathy, dyslipidemia, and primary hypertension. The patient's medications (lisinopril, atorvastatin, metformin, glimepiride) are reviewed and continued. Blood pressure is slightly elevated, and home monitoring is advised. A diabetic foot exam was performed, revealing absent sensation to monofilament on both feet and hard skin on the right foot. Labs ordered include CBC, CMP, HbA1c, Vitamin B12, urine microalbumin, and a lipid panel. Due to the limitations of the provided coding documents, specific ICD-10 codes for the patient's chronic conditions could not be assigned as they were not present in the retrieved documents. Only the HCPCS code for the lipid panel was applicable from the provided list."

# %%
result.ICD10
# Out:
# []

# %%
result.HCPCS
# Out:
# ['80061']
